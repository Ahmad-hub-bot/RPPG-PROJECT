# %% [markdown]
# # Kaggle Runner — thin executor notebook
#
# Develop and debug everything in VS Code locally. This notebook does nothing
# but pull the latest code, attach datasets, and run on Kaggle's GPU.
# Edit the `git clone` URL once you've pushed this repo to GitHub.

# %%
# Cell 1: pull latest code
# !git clone https://github.com/YOUR-USERNAME/rppg-thesis.git
# %cd rppg-thesis
# !pip install -r requirements.txt -q

# %%
# Cell 2: confirm GPU + link Kaggle-attached datasets into expected paths
# !nvidia-smi
# Uncomment and edit once datasets are attached via Add Data:
# !ln -s /kaggle/input/ubfc-rppg-dataset data/raw/UBFC-rPPG
# !ln -s /kaggle/input/mmpd-dataset data/raw/MMPD

# %%
# Cell 3: clone the toolbox itself (kept out of this repo's git history)
# !git clone https://github.com/ubicomplab/rPPG-Toolbox.git

# %%
# Cell 4: run inference sequentially
# !bash scripts/run_all_inference.sh

# %%
# Cell 5: zip results for download
# !zip -r results.zip results/
